# %% [markdown]
# Convert a number base $\beta$ to a decimal number
#
# $$
# (a_na_{n-1}...a_1a_0.b_1b_2b_3...)_{\beta}
# =
# a_n \beta^n + a_{n-1} \beta^{n-1} + ... + a_1 \beta + a_0 + b_1 \beta^{-1} + b_2 \beta^{-2} + b_3 \beta^{-3} + ...
# $$
#
# Common Bases
# * 02 Binary
# * 08 Octal
# * 10 Decimal
# * 16 Hexadecimal
# * 20 Vigesimal
# * 60 Sexagesimal

# %% [markdown]
# Convert $(110111001.101011101)_2$ to base 10.
#
# $$
# \begin{align}
# (110111001.101011101)_2 &= \\
# 1 \times 2^8 &+ \\
# 1 \times 2^7 &+ \\
# 0 \times 2^6 &+ \\
# 1 \times 2^5 &+ \\
# 1 \times 2^4 &+ \\
# 1 \times 2^3 &+ \\
# 0 \times 2^2 &+ \\
# 0 \times 2^1 &+ \\
# 1 \times 2^0 &+ \\
# 1 \times 2^{-1} &+ \\
# 0 \times 2^{-2} &+ \\
# 1 \times 2^{-3} &+ \\
# 0 \times 2^{-4} &+ \\
# 1 \times 2^{-5} &+ \\
# 1 \times 2^{-6} &+ \\
# 1 \times 2^{-7} &+ \\
# 0 \times 2^{-8} &+ \\
# 1 \times 2^{-9} &= \\
# 2^8 + 2^7 + 2^5 + 2^4 + 2^3 + 2^0 + 2^{-1} + 2^{-3} + 2^{-5} + 2^{-6} + 2^{-7} + 2^{-9} &= \\
# 256 + 128 + 32 + 16 + 8 + 1 + \frac{1}{2} + \frac{1}{8} + \frac{1}{32} + \frac{1}{64} + \frac{1}{128} + \frac{1}{512} &= \\
# 441 + \frac{256}{512} + \frac{64}{512} + \frac{16}{512} + \frac{8}{512} + \frac{4}{512} + \frac{1}{512} &= \\
# 441 + \frac{349}{512} &= \\
# (441.681640625)_{10} & \\
# \end{align}
# $$
#
# $$
# \begin{align}
# 2 | 441 &= 220 + 2 | 1 \\
# 2 | 220 &= 110 + 2 | 0 \\
# 2 | 110 &= 055 + 2 | 0 \\
# 2 |  55 &= 027 + 2 | 1 \\
# 2 |  27 &= 013 + 2 | 1 \\
# 2 |  13 &= 006 + 2 | 1 \\
# 2 |   6 &= 003 + 2 | 0 \\
# 2 |   3 &= 001 + 2 | 1 \\
# 2 |   1 &= 000 + 2 | 1 \\
# 2 * 0.681640625 &= 0.36328125 + 1 \\
# 2 * 0.36328125  &= 0.7265625  + 0 \\
# 2 * 0.7265625   &= 0.453125   + 1 \\
# 2 * 0.453125    &= 0.90625    + 0 \\
# 2 * 0.90625     &= 0.8125     + 1 \\
# 2 * 0.8125      &= 0.625      + 1 \\
# 2 * 0.625       &= 0.25       + 1 \\
# 2 * 0.25        &= 0.5        + 0 \\
# 2 * 0.5         &= 0.0        + 1 \\
# \end{align}
# $$

# %% [markdown]
# Convert $(1001100101.01101)_2$ to base 10.
#
# $$
# \begin{align}
# (1001100101.01101)_2 &= \\
# 1 \times 2^9 &+ \\
# 0 \times 2^8 &+ \\
# 0 \times 2^7 &+ \\
# 1 \times 2^6 &+ \\
# 1 \times 2^5 &+ \\
# 0 \times 2^4 &+ \\
# 0 \times 2^3 &+ \\
# 1 \times 2^2 &+ \\
# 0 \times 2^1 &+ \\
# 1 \times 2^0 &+ \\
# 0 \times 2^{-1} &+ \\
# 1 \times 2^{-2} &+ \\
# 1 \times 2^{-3} &+ \\
# 0 \times 2^{-4} &+ \\
# 1 \times 2^{-5} &= \\
# 2^9 + 2^6 + 2^5 + 2^2 + 2^0 + 2^{-2} + 2^{-3} + 2^{-5} &= \\
# 512 + 64 + 32 + 4 + 1 + \frac{1}{4} + \frac{1}{8} + \frac{1}{32} &= \\
# 613 + \frac{8}{32} + \frac{4}{32} + \frac{1}{32} &= \\
# 613 + \frac{13}{32} &= \\
# (613.40625)_{10} & \\
# \end{align}
# $$
#
# $$
# \begin{align}
# 2 | 613 &= 306 + 2 | 1 \\
# 2 | 306 &= 153 + 2 | 0 \\
# 2 | 153 &= 076 + 2 | 1 \\
# 2 |  76 &= 038 + 2 | 0 \\
# 2 |  38 &= 019 + 2 | 0 \\
# 2 |  19 &= 009 + 2 | 1 \\
# 2 |   9 &= 004 + 2 | 1 \\
# 2 |   4 &= 002 + 2 | 0 \\
# 2 |   2 &= 001 + 2 | 0 \\
# 2 |   1 &= 000 + 2 | 1 \\
# 2 * 0.40625 &= 0.8125 + 0 \\
# 2 * 0.8125  &= 0.625  + 1 \\
# 2 * 0.625   &= 0.25   + 1 \\
# 2 * 0.25    &= 0.5    + 0 \\
# 2 * 0.5     &= 0.0    + 1 \\
# \end{align}
# $$

# %% [markdown]
# Convert $(101.01)_2$ to base 10.
#
# $$
# \begin{align}
# (101.01)_2 &= \\
# 1 \times 2^2 &+ \\
# 0 \times 2^1 &+ \\
# 1 \times 2^0 &+ \\
# 0 \times 2^{-1} &+ \\
# 1 \times 2^{-2} &= \\
# 2^2 + 2^0 + 2^{-2} &= \\
# 4 + 1 + \frac{1}{4} &= \\
# 5 + \frac{1}{4} &= \\
# (5.25)_{10} & \\
# \end{align}
# $$
#
# $$
# \begin{align}
# 2 | 5 &= 2 + 2 | 1 \\
# 2 | 2 &= 1 + 2 | 0 \\
# 2 | 1 &= 0 + 2 | 1 \\
# 2 * 0.25 &= 0.5 + 0 \\
# 2 * 0.5  &= 0.0 + 1 \\
# \end{align}
# $$

# %% [markdown]
# Convert $(100.01)_{10}$ to base 2.
#
# $$
# \begin{align}
# 2 | 100 &= 50 + 2 | 0 \\
# 2 |  50 &= 25 + 2 | 0 \\
# 2 |  25 &= 12 + 2 | 1 \\
# 2 |  12 &= 06 + 2 | 0 \\
# 2 |   6 &= 03 + 2 | 0 \\
# 2 |   3 &= 01 + 2 | 1 \\
# 2 |   1 &= 00 + 2 | 1 \\
# 2 * 0.1 &= 0.2 + 0 \\
# 2 * 0.2 &= 0.4 + 0 \\
# 2 * 0.4 &= 0.8 + 0 \\
# 2 * 0.8 &= 0.6 + 1 \\
# 2 * 0.6 &= 0.2 + 1 \\
# 2 * 0.2 &= 0.4 + 0 \\
# 2 * 0.4 &= 0.8 + 0 \\
# 2 * 0.8 &= 0.6 + 1 \\
# 2 * 0.6 &= 0.2 + 1 \\
# 2 * 0.2 &= 0.4 + 0 \\
# ... &
# \end{align}
# $$
#
# $$
# \begin{align}
# (1100100.0001100110)_2 &= \\
# 1 \times 2^6 &+ \\
# 1 \times 2^5 &+ \\
# 0 \times 2^4 &+ \\
# 0 \times 2^3 &+ \\
# 1 \times 2^2 &+ \\
# 0 \times 2^1 &+ \\
# 0 \times 2^0 &+ \\
# 0 \times 2^{-1} &+ \\
# 0 \times 2^{-2} &+ \\
# 0 \times 2^{-3} &+ \\
# 1 \times 2^{-4} &+ \\
# 1 \times 2^{-5} &+ \\
# 0 \times 2^{-6} &+ \\
# 0 \times 2^{-7} &+ \\
# 1 \times 2^{-8} &+ \\
# 1 \times 2^{-9} &+ \\
# 0 \times 2^{-10} &= \\
# 2^6 + 2^5 + 2^2 + 2^{-4} + 2^{-5} + 2^{-8} + 2^{-9} &= \\
# 64 + 32 + 4 + \frac{1}{16} + \frac{1}{32} + \frac{1}{256} + \frac{1}{512} &= \\
# 100 + \frac{32}{512} + \frac{16}{512} + \frac{2}{512} + \frac{1}{512} &= \\
# 100 + \frac{51}{512} &= \\
# (100.099609375)_{10} & \\
# \end{align}
# $$

# %% [markdown]
# Convert $(64.625)_{10}$ to base 2.
#
# $$
# \begin{align}
# 2 | 64 &= 32 + 2 | 0 \\
# 2 | 32 &= 16 + 2 | 0 \\
# 2 | 16 &= 08 + 2 | 0 \\
# 2 |  8 &= 04 + 2 | 0 \\
# 2 |  4 &= 02 + 2 | 0 \\
# 2 |  2 &= 01 + 2 | 0 \\
# 2 |  1 &= 00 + 2 | 1 \\
# 2 * 0.625 &= 0.25 + 1 \\
# 2 * 0.25  &= 0.5  + 0 \\
# 2 * 0.5   &= 0.0  + 1 \\
# \end{align}
# $$
#
# $$
# \begin{align}
# (1000000.101)_2 &= \\
# 1 \times 2^6 &+ \\
# 0 \times 2^5 &+ \\
# 0 \times 2^4 &+ \\
# 0 \times 2^3 &+ \\
# 0 \times 2^2 &+ \\
# 0 \times 2^1 &+ \\
# 0 \times 2^0 &+ \\
# 1 \times 2^{-1} &+ \\
# 0 \times 2^{-2} &+ \\
# 1 \times 2^{-3} &= \\
# 2^6 + 2^{-1} + 2^{-3} &= \\
# 64 + \frac{1}{2} + \frac{1}{8} &= \\
# 64 + \frac{5}{8} &= \\
# (64.625)_{10} & \\
# \end{align}
# $$
